# %%
# !pip3 install grid2op[optional]
# Out:
# Collecting grid2op[optional]
#   Downloading Grid2Op-1.10.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (1.26.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (1.13.1)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (2.2.2)
# Collecting pandapower>=2.2.2 (from grid2op[optional])
#   Downloading pandapower-2.14.11.zip (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 101.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.45.0 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (4.66.5)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (3.4.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (2.32.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (24.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (4.12.2)
# Requirement already satisfied: nbformat>=5.0.4 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (5.10.4)
# Requirement already satisfied: jupyter-client>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (6.1.12)
# Collecting jyquickhelper>=0.3.128 (from grid2op[optional])
#   Downloading jyquickhelper-0.4.220-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: numba>=0.48.0 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (0.60.0)
# Requirement already satisfied: matplotlib>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (3.7.1)
# Requirement already satisfied: plotly>=4.5.4 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (5.24.1)
# Requirement already satisfied: seaborn>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (0.13.2)
# Requirement already satisfied: imageio>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (2.35.1)
# Collecting pygifsicle>=1.0.1 (from grid2op[optional])
#   Downloading pygifsicle-1.1.0.tar.gz (5.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from grid2op[optional]) (5.9.5)
# Collecting gymnasium (from grid2op[optional])
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting lightsim2grid (from grid2op[optional])
#   Downloading LightSim2Grid-0.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.8.0->grid2op[optional]) (10.4.0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.0->grid2op[optional]) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.0->grid2op[optional]) (5.7.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.0->grid2op[optional]) (24.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.0->grid2op[optional]) (2.8.2)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.0->grid2op[optional]) (6.3.3)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from jyquickhelper>=0.3.128->grid2op[optional]) (7.34.0)
# Collecting jupyter (from jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jyquickhelper>=0.3.128->grid2op[optional]) (6.5.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.1->grid2op[optional]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.1->grid2op[optional]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.1->grid2op[optional]) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.1->grid2op[optional]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.1->grid2op[optional]) (3.2.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.0.4->grid2op[optional]) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.0.4->grid2op[optional]) (4.23.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.48.0->grid2op[optional]) (0.43.0)
# Collecting deepdiff (from pandapower>=2.2.2->grid2op[optional])
#   Downloading deepdiff-8.0.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->grid2op[optional]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->grid2op[optional]) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.5.4->grid2op[optional]) (9.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->grid2op[optional]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->grid2op[optional]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->grid2op[optional]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->grid2op[optional]) (2024.8.30)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->grid2op[optional]) (3.1.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium->grid2op[optional])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightsim2grid->grid2op[optional]) (75.1.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from lightsim2grid->grid2op[optional]) (24.1.2)
# Collecting pybind11 (from lightsim2grid->grid2op[optional])
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.0.4->grid2op[optional]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.0.4->grid2op[optional]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.0.4->grid2op[optional]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.0.4->grid2op[optional]) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.0->grid2op[optional]) (4.3.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client>=6.1.0->grid2op[optional]) (1.16.0)
# Collecting orderly-set==5.2.2 (from deepdiff->pandapower>=2.2.2->grid2op[optional])
#   Downloading orderly_set-5.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jedi>=0.16 (from ipython->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->jyquickhelper>=0.3.128->grid2op[optional]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->jyquickhelper>=0.3.128->grid2op[optional]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->jyquickhelper>=0.3.128->grid2op[optional]) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->jyquickhelper>=0.3.128->grid2op[optional]) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->jyquickhelper>=0.3.128->grid2op[optional]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->jyquickhelper>=0.3.128->grid2op[optional]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->jyquickhelper>=0.3.128->grid2op[optional]) (4.9.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (6.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (7.7.1)
# Collecting jupyterlab (from jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (3.1.4)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (23.1.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jyquickhelper>=0.3.128->grid2op[optional]) (1.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->jyquickhelper>=0.3.128->grid2op[optional]) (0.8.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jyquickhelper>=0.3.128->grid2op[optional]) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (3.0.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (1.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->jyquickhelper>=0.3.128->grid2op[optional]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jyquickhelper>=0.3.128->grid2op[optional]) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jyquickhelper>=0.3.128->grid2op[optional]) (21.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (3.0.13)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting ipykernel (from jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: tomli>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (2.0.2)
# Collecting comm>=0.1.1 (from ipykernel->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (1.6.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (3.7.1)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jupyter-client>=6.1.0 (from grid2op[optional])
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (2.16.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jyquickhelper>=0.3.128->grid2op[optional]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (0.5.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (1.2.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jyquickhelper>=0.3.128->grid2op[optional]) (2.22)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional]) (24.8.0)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->jyquickhelper>=0.3.128->grid2op[optional])
#   Downloading types_python_dateutil-2.9.0.20241003-py3-none-any.whl.metadata (1.9 kB)
# Downloading jyquickhelper-0.4.220-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.8 MB/s eta 0:00:00
# Downloading Grid2Op-1.10.5-py3-none-any.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 36.3 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 46.7 MB/s eta 0:00:00
# Downloading LightSim2Grid-0.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.8/853.8 kB 50.6 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading deepdiff-8.0.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 8.3 MB/s eta 0:00:00
# Downloading orderly_set-5.2.2-py3-none-any.whl (11 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 22.6 MB/s eta 0:00:00
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.7 MB/s eta 0:00:00
# Downloading jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 100.3 MB/s eta 0:00:00
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 10.3 MB/s eta 0:00:00
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 7.7 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 7.2 MB/s eta 0:00:00
# Downloading jupyter_server-2.14.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 34.5 MB/s eta 0:00:00
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 13.3 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 6.0 MB/s eta 0:00:00
# Downloading json5-0.9.25-py3-none-any.whl (30 kB)
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.8 MB/s eta 0:00:00
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.2 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241003-py3-none-any.whl (9.7 kB)
# Building wheels for collected packages: pandapower, pygifsicle
#   Building wheel for pandapower (setup.py) ... done
#   Created wheel for pandapower: filename=pandapower-2.14.11-py3-none-any.whl size=13131028 sha256=abd8cbb66a6eec884b1a71e516317ac465e51609f091dc3e4dc2d89353389071
#   Stored in directory: /root/.cache/pip/wheels/7f/de/5a/7b00f385eb06d1fb1f7c1cd06f9bb901709c038d3899548cf1
#   Building wheel for pygifsicle (setup.py) ... done
#   Created wheel for pygifsicle: filename=pygifsicle-1.1.0-py3-none-any.whl size=4994 sha256=992875c0a66e51b50df14d5072db0609d203650fadd7e7a65e6995fe3456f508
#   Stored in directory: /root/.cache/pip/wheels/4a/5e/df/706ac0af090eef3eee4024abc53929cd9aaae4d94b881d4f96
# Successfully built pandapower pygifsicle
# Installing collected packages: pygifsicle, farama-notifications, uri-template, types-python-dateutil, rfc3986-validator, rfc3339-validator, python-json-logger, pybind11, overrides, orderly-set, jsonpointer, json5, jedi, h11, gymnasium, fqdn, comm, async-lru, lightsim2grid, jupyter-server-terminals, jupyter-client, httpcore, deepdiff, arrow, pandapower, isoduration, ipykernel, httpx, grid2op, jupyter-events, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, jyquickhelper
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.29.5 which is incompatible.
# Successfully installed arrow-1.3.0 async-lru-2.0.4 comm-0.2.2 deepdiff-8.0.1 farama-notifications-0.0.4 fqdn-1.5.1 grid2op-1.10.5 gymnasium-1.0.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 ipykernel-6.29.5 isoduration-20.11.0 jedi-0.19.1 json5-0.9.25 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-client-7.4.9 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-server-2.27.3 jyquickhelper-0.4.220 lightsim2grid-0.9.2 orderly-set-5.2.2 overrides-7.7.0 pandapower-2.14.11 pybind11-2.13.6 pygifsicle-1.1.0 python-json-logger-2.0.7 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 types-python-dateutil-2.9.0.20241003 uri-template-1.3.0

# %%
# !git clone https://github.com/grid2op/Grid2Op.git
# !cd Grid2Op
# !pip3 install -U .
# !cd ..
# Out:
# Cloning into 'Grid2Op'...
# remote: Enumerating objects: 29036, done.
# remote: Counting objects: 100% (5811/5811), done.
# remote: Compressing objects: 100% (1827/1827), done.
# remote: Total 29036 (delta 4010), reused 5282 (delta 3909), pack-reused 23225 (from 1)
# Receiving objects: 100% (29036/29036), 87.82 MiB | 20.64 MiB/s, done.
# Resolving deltas: 100% (21119/21119), done.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !pip install wandb
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.5)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.17.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.5.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 5.7 MB/s eta 0:00:00
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 16.0 MB/s eta 0:00:00
# Installing collected packages: gymnasium, stable_baselines3
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0
#     Uninstalling gymnasium-1.0.0:
#       Successfully uninstalled gymnasium-1.0.0
# Successfully installed gymnasium-0.29.1 stable_baselines3-2.3.2

# %%
import gymnasium as gym

import grid2op
import copy
from typing import Dict, Literal, Any, OrderedDict, Optional, Tuple, Union
from grid2op import gym_compat
from grid2op.Parameters import Parameters
from grid2op.Action import PlayableAction
from grid2op.Observation import CompleteObservation
from grid2op.Reward import L2RPNReward, N1Reward, CombinedScaledReward, LinesCapacityReward, LinesReconnectedReward, CloseToOverflowReward , AlertReward
from stable_baselines3 import PPO, DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from gymnasium.spaces import Discrete, MultiDiscrete, Box
from grid2op.gym_compat import GymEnv, BoxGymObsSpace, DiscreteActSpace, BoxGymActSpace, MultiDiscreteActSpace, ContinuousToDiscreteConverter
from gymnasium import spaces
from lightsim2grid import LightSimBackend
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
import wandb
from wandb.integration.sb3 import WandbCallback
import numpy as np
from stable_baselines3 import DQN, HerReplayBuffer
from stable_baselines3.common.buffers import ReplayBuffer
from stable_baselines3.her.goal_selection_strategy import GoalSelectionStrategy # 'final', 'episode', 'future'
import matplotlib.pyplot as plt
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:55: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation

# %%
# Gymnasium environment wrapper around Grid2Op environment
class Gym2OpEnvWrapper(gym.Env):
    def __init__(
            self,env_config: Dict[Literal["backend_cls",
                                          "backend_options",
                                          "env_name",
                                          "env_is_test",
                                          "obs_attr_to_keep",
                                          "act_type",
                                          "act_attr_to_keep"],
                                  Any] = None,
            reward_class=CombinedScaledReward,
            other_rewards = {},
            use_rewards=True, baseline=True):

        super().__init__()
        if env_config is None:
            self.env_config = {}
        else:
            self.env_config=env_config

        backend_cls = LightSimBackend
        if "backend_cls" in self.env_config:
            backend_cls = self.env_config["backend_cls"]
        backend_options = {}
        if "backend_options" in self.env_config:
            backend_options = self.env_config["backend_options"]
        self._backend = backend_cls(**backend_options)

        #self._backend = LightSimBackend()
        self._env_name = "l2rpn_case14_sandbox"  # DO NOT CHANGE
        self.baseline = baseline
        action_class = PlayableAction
        observation_class = CompleteObservation
        self.reward_class = reward_class # Setup further below
        self.other_rewards = other_rewards

        # DO NOT CHANGE Parameters
        # See https://grid2op.readthedocs.io/en/latest/parameters.html
        p = Parameters()
        p.MAX_SUB_CHANGED = 4  # Up to 4 substations can be reconfigured each timestep
        p.MAX_LINE_STATUS_CHANGED = 4  # Up to 4 powerline statuses can be changed each timestep

        if use_rewards:
            # Make grid2op env
            self._g2op_env = grid2op.make(
                self._env_name, backend=self._backend, test=False,
                action_class=action_class, observation_class=observation_class,
                reward_class=self.reward_class, param=p, other_rewards=self.other_rewards
            )

        ##########
        # REWARD #
        ##########
        # NOTE: This reward should not be modified when evaluating RL agent
        # See https://grid2op.readthedocs.io/en/latest/reward.html
        else:
            self._g2op_env = grid2op.make(
                self._env_name, backend=self._backend, test=False,
                action_class=action_class, observation_class=observation_class,
                reward_class=self.reward_class, param=p
            )

        cr = self._g2op_env.get_reward_instance()
        cr.addReward("N1", N1Reward(), 1.0)
        cr.addReward("L2RPN", L2RPNReward(), 1.0)
        #reward = N1 + L2RPN
        cr.initialize(self._g2op_env)
        ##########

        self._gym_env = gym_compat.GymEnv(self._g2op_env)

        self.setup_observations()
        self.setup_actions()

        self.observation_space = self.setup_observations()
        self.action_space = self.setup_actions()

    def setup_observations(self):
        #print("WARNING: setup_actions is not doing anything. Implement your own code in this method.")

        if self.baseline:
            self._gym_env.observation_space.close()
            self._gym_env.observation_space = BoxGymObsSpace(self._g2op_env.observation_space)
            return Box(shape=self._gym_env.observation_space.shape,
                                     low=self._gym_env.observation_space.low,
                                     high=self._gym_env.observation_space.high)

        obs_attr_to_keep = ["rho", "p_or", "gen_p", "load_p"]
        if "obs_attr_to_keep" in self.env_config:
            obs_attr_to_keep = copy.deepcopy(self.env_config["obs_attr_to_keep"])
        self._gym_env.observation_space.close()
        self._gym_env.observation_space = BoxGymObsSpace(self._g2op_env.observation_space,
                                                         attr_to_keep=obs_attr_to_keep
                                                         )
        # export observation space for the Grid2opEnv
        observation_space = Box(shape=self._gym_env.observation_space.shape,
                                     low=self._gym_env.observation_space.low,
                                     high=self._gym_env.observation_space.high)
        return observation_space

    def setup_actions(self):
        # TODO: Your code to specify & modify the action space goes here
        # See Grid2Op 'getting started' notebooks for guidance
        #  - Notebooks: https://github.com/rte-france/Grid2Op/tree/master/getting_started
        #print("WARNING: setup_actions is not doing anything. Implement your own code in this method.")

        act_type = "discrete"
        if "discrete" in self.env_config:
            act_type = self.env_config["act_type"]

        self._gym_env.action_space.close()
        if act_type == "discrete" and not self.baseline:
            # user wants a discrete action space
            act_attr_to_keep =  ["set_line_status","redispatch","set_bus"]
            if "act_attr_to_keep" in self.env_config:
                act_attr_to_keep = copy.deepcopy(self.env_config["act_attr_to_keep"])
            self._gym_env.action_space = DiscreteActSpace(self._g2op_env.action_space,
                                                          attr_to_keep=act_attr_to_keep)
            action_space = Discrete(self._gym_env.action_space.n)
        else:
            self._gym_env.action_space = DiscreteActSpace(self._g2op_env.action_space)

            action_space = Discrete(self._gym_env.action_space.n)


        return action_space

    def reset(self, seed=None):
        return self._gym_env.reset(seed=seed, options=None)

    def step(self, action):
        return self._gym_env.step(action)

    def render(self):
        # TODO: Modify for your own required usage
        return self._gym_env.render()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   def _forward_input(self, allow_stdin=False):

# %% [markdown]
# ## DQN agent interacting in environment

# %% [markdown]
# ## Baseline Model

# %%
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 20000,
    "env_name": "l2rpn_case14_sandbox",
}
run = wandb.init(
    project="RL_Final",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)


def make_env():
    env = Gym2OpEnvWrapper(use_rewards=False)
    env = Monitor(env)  # record stats such as returns
    return env


env = DummyVecEnv([make_env])
# env = VecVideoRecorder(
#     env,
#     f"videos/{run.id}",
#     record_video_trigger=lambda x: x % 2000 == 0,
#     video_length=200,
# )
model_baseline = DQN(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}", target_update_interval=0, gradient_steps=1)
model_baseline.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        gradient_save_freq=1,
        model_save_path=f"DQN_Final/{run.id}",
        verbose=1,
    ),
)
run.finish()
env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/notebook/utils.py:280: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   return LooseVersion(v) >= LooseVersion(check)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241028_164523-fzy583zv</code>
# Syncing run <strong><a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/fzy583zv' target="_blank">vibrant-pine-8</a></strong> to <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a>
#  View run at <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/fzy583zv' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/fzy583zv</a>
# /usr/local/lib/python3.10/dist-packages/grid2op/MakeEnv/Make.py:506: UserWarning: It is the first time you use the environment "l2rpn_case14_sandbox".
# We will attempt to download this environment from remote
#   warnings.warn(_MAKE_FIRST_TIME_WARN.format(dataset_name))
# downloading the training data, this may take a while.
# l2rpn_case14_sandbox.tar.bz2: 294MB [00:33, 8.85MB/s]
# Extract the tar archive in "/root/data_grid2op"
# 	 Successfully updated file "config.py" for environment "l2rpn_case14_sandbox"
# 	 Successfully updated file "grid.json" for environment "l2rpn_case14_sandbox"
# You may now use the environment "l2rpn_case14_sandbox" with the available data by invoking:
# 	env = grid2op.make("l2rpn_case14_sandbox")
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "curtail" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# Using cuda device
# Logging to runs/fzy583zv/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 16       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88     |
# |    ep_rew_mean      | 0.242    |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 22       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17     |
# |    ep_rew_mean      | 0.281    |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 25       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 50       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88     |
# |    ep_rew_mean      | 0.237    |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 24       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 62       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 0.327    |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 27       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 85       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | 0.248    |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 25       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 95       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07     |
# |    ep_rew_mean      | 0.301    |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 20       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 114      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 68.9     |
# |    n_updates        | 3        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | 0.351    |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 22       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 135      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 74.6     |
# |    n_updates        | 8        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | 0.312    |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 22       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 149      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 70.9     |
# |    n_updates        | 12       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | 0.258    |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 21       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 159      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 82       |
# |    n_updates        | 14       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 21       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 174      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 75.3     |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9      |
# |    ep_rew_mean      | 0.244    |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 20       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 187      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.8     |
# |    n_updates        | 21       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4        |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 21       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 208      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 69.7     |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 21       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 233      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 54.6     |
# |    n_updates        | 33       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.286    |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 21       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 243      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.9     |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | 0.297    |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 21       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 263      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.3     |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.272    |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 21       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 274      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 47.2     |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | 0.258    |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 21       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 285      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 50.7     |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.247    |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 21       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 298      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 57       |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | 0.229    |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 21       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 308      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 51.6     |
# |    n_updates        | 51       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87     |
# |    ep_rew_mean      | 0.228    |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 21       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 325      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 50.6     |
# |    n_updates        | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | 0.236    |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 21       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 342      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.7     |
# |    n_updates        | 60       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | 0.239    |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 22       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 358      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.8     |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86     |
# |    ep_rew_mean      | 0.235    |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 22       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 371      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 47.4     |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | 0.222    |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 21       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 381      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 53.7     |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | 0.233    |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 22       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 398      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 55.3     |
# |    n_updates        | 74       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.594    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 22       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 427      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 49.6     |
# |    n_updates        | 81       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94     |
# |    ep_rew_mean      | 0.269    |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 23       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 444      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 44.9     |
# |    n_updates        | 85       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.285    |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 23       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 464      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.2     |
# |    n_updates        | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.258    |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 23       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 477      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.6     |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01     |
# |    ep_rew_mean      | 0.278    |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 23       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 496      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.1     |
# |    n_updates        | 98       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 23       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 516      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.4     |
# |    n_updates        | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07     |
# |    ep_rew_mean      | 0.297    |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 23       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 542      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34       |
# |    n_updates        | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39     |
# |    ep_rew_mean      | 0.401    |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 24       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 588      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.5     |
# |    n_updates        | 121      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.44     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.427    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 24       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 603      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.4     |
# |    n_updates        | 125      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.55     |
# |    ep_rew_mean      | 0.446    |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 24       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 629      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.5     |
# |    n_updates        | 132      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.57     |
# |    ep_rew_mean      | 0.453    |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 24       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 644      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.7     |
# |    n_updates        | 135      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.56     |
# |    ep_rew_mean      | 0.453    |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 24       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 664      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.1     |
# |    n_updates        | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.55     |
# |    ep_rew_mean      | 0.451    |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 24       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 688      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 30.6     |
# |    n_updates        | 146      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.92     |
# |    ep_rew_mean      | 0.55     |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 25       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 735      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.1     |
# |    n_updates        | 158      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.04     |
# |    ep_rew_mean      | 0.582    |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 26       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 767      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 32.1     |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.18     |
# |    ep_rew_mean      | 0.624    |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 26       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 792      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 25.8     |
# |    n_updates        | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.42     |
# |    ep_rew_mean      | 0.696    |
# |    exploration_rate | 0.214    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 27       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 827      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.4     |
# |    n_updates        | 181      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.49     |
# |    ep_rew_mean      | 0.722    |
# |    exploration_rate | 0.195    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 27       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 847      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.1     |
# |    n_updates        | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.46     |
# |    ep_rew_mean      | 0.714    |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 26       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 854      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 28.6     |
# |    n_updates        | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.35     |
# |    ep_rew_mean      | 0.691    |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 26       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 860      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 31       |
# |    n_updates        | 189      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.65     |
# |    ep_rew_mean      | 0.808    |
# |    exploration_rate | 0.138    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 27       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 907      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.4     |
# |    n_updates        | 201      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.53     |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 29       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1011     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 50.8     |
# |    n_updates        | 227      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.3      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 30       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 1101     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.4     |
# |    n_updates        | 250      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.45     |
# |    ep_rew_mean      | 1.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 32       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 1226     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.1     |
# |    n_updates        | 281      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.86     |
# |    ep_rew_mean      | 1.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 33       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 1284     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 28       |
# |    n_updates        | 295      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.87     |
# |    ep_rew_mean      | 1.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 33       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 1314     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 41.9     |
# |    n_updates        | 303      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.55     |
# |    ep_rew_mean      | 1.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 34       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1399     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37       |
# |    n_updates        | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.53     |
# |    ep_rew_mean      | 1.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 34       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1417     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 20       |
# |    n_updates        | 329      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66     |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 34       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 1443     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 22.2     |
# |    n_updates        | 335      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.62     |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 34       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 1458     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 28.1     |
# |    n_updates        | 339      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 33       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 1487     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 48.3     |
# |    n_updates        | 346      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.55     |
# |    ep_rew_mean      | 1.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 33       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 1497     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.6     |
# |    n_updates        | 349      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.21     |
# |    ep_rew_mean      | 1.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 32       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 1509     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 55.4     |
# |    n_updates        | 352      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.19     |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 32       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 1522     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 40.7     |
# |    n_updates        | 355      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.07     |
# |    ep_rew_mean      | 1.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 32       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 1536     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 46.1     |
# |    n_updates        | 358      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 32       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 1612     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 54.2     |
# |    n_updates        | 377      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.58     |
# |    ep_rew_mean      | 1.91     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 32       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 1622     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 31.4     |
# |    n_updates        | 380      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.49     |
# |    ep_rew_mean      | 1.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 32       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 1637     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.2     |
# |    n_updates        | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.14     |
# |    ep_rew_mean      | 1.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 32       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 1649     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 62       |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05     |
# |    ep_rew_mean      | 1.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 32       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 1672     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 59.5     |
# |    n_updates        | 392      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.9      |
# |    ep_rew_mean      | 1.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 31       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 1682     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 31.3     |
# |    n_updates        | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.64     |
# |    ep_rew_mean      | 1.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 31       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 1691     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 46.4     |
# |    n_updates        | 397      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.52     |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 31       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 1699     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 68.4     |
# |    n_updates        | 399      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.53     |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 31       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 1707     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 78.6     |
# |    n_updates        | 401      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.55     |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 31       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 1715     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 77.6     |
# |    n_updates        | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.28     |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 31       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 1735     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 47.2     |
# |    n_updates        | 408      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.46     |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 31       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 1757     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 46       |
# |    n_updates        | 414      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.66     |
# |    ep_rew_mean      | 0.932    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 31       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 1767     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 41.8     |
# |    n_updates        | 416      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.5      |
# |    ep_rew_mean      | 0.577    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 31       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 1776     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 89.9     |
# |    n_updates        | 418      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.03     |
# |    ep_rew_mean      | 0.416    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 30       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 1787     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 60.1     |
# |    n_updates        | 421      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.84     |
# |    ep_rew_mean      | 0.373    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 30       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 1798     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 84.8     |
# |    n_updates        | 424      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# |    ep_rew_mean      | 0.158    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 30       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 1809     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.2     |
# |    n_updates        | 427      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 30       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 1822     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 55.4     |
# |    n_updates        | 430      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | 0.107    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 30       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 1832     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.8     |
# |    n_updates        | 432      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | 0.0999   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 30       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 1840     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.8     |
# |    n_updates        | 434      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65     |
# |    ep_rew_mean      | 0.0598   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 30       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 1852     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 76.8     |
# |    n_updates        | 437      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06     |
# |    ep_rew_mean      | 0.203    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 30       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 1903     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 59       |
# |    n_updates        | 450      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06     |
# |    ep_rew_mean      | 0.203    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 30       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 1915     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 86.8     |
# |    n_updates        | 453      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.197    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 30       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 1927     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.1     |
# |    n_updates        | 456      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | 0.213    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 30       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 1944     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 61.5     |
# |    n_updates        | 460      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64     |
# |    ep_rew_mean      | 0.111    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 30       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 1976     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 48.9     |
# |    n_updates        | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    episodes         | 1000     |
# |    fps              | 45       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 9232     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 322      |
# |    n_updates        | 2282     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 3.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 45       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 9248     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 118      |
# |    n_updates        | 2286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 3.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 45       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 9260     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 362      |
# |    n_updates        | 2289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 3.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 45       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 9272     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 171      |
# |    n_updates        | 2292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 3.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 45       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 9284     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 375      |
# |    n_updates        | 2295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 3.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 45       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 9385     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 611      |
# |    n_updates        | 2321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 3.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 45       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 9436     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 350      |
# |    n_updates        | 2333     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 45       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 9448     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 465      |
# |    n_updates        | 2336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 3.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 45       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 9464     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 123      |
# |    n_updates        | 2340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 3.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 46       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 9609     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 491      |
# |    n_updates        | 2377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 3.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 46       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 9624     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 295      |
# |    n_updates        | 2380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 3.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 46       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 9636     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 346      |
# |    n_updates        | 2383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 3.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 46       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 9648     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 190      |
# |    n_updates        | 2386     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 3.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 45       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 9660     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 413      |
# |    n_updates        | 2389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 2.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 45       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 9672     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 511      |
# |    n_updates        | 2392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 2.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 45       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 9684     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 583      |
# |    n_updates        | 2395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 2.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 45       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 9696     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 368      |
# |    n_updates        | 2398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 2.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 45       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 9823     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 327      |
# |    n_updates        | 2430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 2.91     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 45       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 9854     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 381      |
# |    n_updates        | 2438     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 2.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 45       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 9873     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 963      |
# |    n_updates        | 2443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 2.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 45       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 9886     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 615      |
# |    n_updates        | 2446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 2.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 45       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 9898     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 404      |
# |    n_updates        | 2449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 2.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 45       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 9910     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 398      |
# |    n_updates        | 2452     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 2.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 45       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 9921     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 990      |
# |    n_updates        | 2455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.68     |
# |    ep_rew_mean      | 1.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 45       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 9965     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 261      |
# |    n_updates        | 2466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.49     |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 45       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 9981     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 441      |
# |    n_updates        | 2470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.45     |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 45       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 9993     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 171      |
# |    n_updates        | 2473     |
# ----------------------------------
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▂▂▂▂▅▅▅▁▁▁▂▂▄▄▅▆▆▇▇▃▅▃▅▅▄▄▅██▇██▇▇</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂▃▄▄▄▄▄▁▁▁▂▂▄▄▄▄▄▅▆▅▄▄▅▅▆▅▄▄▄███▆▅▇▆▆</td></tr><tr><td>rollout/exploration_rate</td><td>█▇▆▆▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▂▂▁▁▁▂▂▂▅▅▄▄▄▄▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇███</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▂▁▁▁▁▁▁▁▁▁▁▂▂▁▂▁▂▁▂▂▂▂▃▃▃▃▂▂▄▆▄▄▆▅▅▅█▄▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>9993</td></tr><tr><td>rollout/ep_len_mean</td><td>7.45</td></tr><tr><td>rollout/ep_rew_mean</td><td>1.43425</td></tr><tr><td>rollout/exploration_rate</td><td>0.05</td></tr><tr><td>time/fps</td><td>45</td></tr><tr><td>train/learning_rate</td><td>0.0001</td></tr><tr><td>train/loss</td><td>171.06886</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vibrant-pine-8</strong> at: <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/fzy583zv' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/fzy583zv</a><br/> View project at: <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20241028_164523-fzy583zv/logs</code>

# %%
env = Gym2OpEnvWrapper(use_rewards=False)
evaluate_policy(model_baseline, env, n_eval_episodes=200, render=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "curtail" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (2.280706320567988, 1.7435409181229242)

# %%
env.close()

# %%
def evaluate_and_plot(model, model_name, eval_env, periods=[5, 20, 100, 200, 300]):
    """
    Evaluate model over different numbers of episodes and plot results

    Args:
        model: The trained model to evaluate
        eval_env: The evaluation environment
        periods: List of episodes to evaluate over
    """
    mean_rewards = []
    std_rewards = []

    # Evaluate for each period
    for n_episodes in periods:
        mean_reward, std_reward = evaluate_policy(
            model,
            eval_env,
            n_eval_episodes=n_episodes,
            deterministic=True
        )
        mean_rewards.append(mean_reward)
        std_rewards.append(std_reward)

    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.errorbar(periods, mean_rewards, yerr=std_rewards,
                fmt='o-', capsize=5, capthick=1, elinewidth=1)

    plt.xlabel('Number of Episodes')
    plt.ylabel('Mean Reward')
    plt.title(f'{model_name} Model Performance Over Different Evaluation Periods')
    plt.grid(True)

    # Print numerical results
    for period, mean, std in zip(periods, mean_rewards, std_rewards):
        print(f"Episodes: {period}, Mean: {mean:.2f}, Std: {std:.2f}")

    plt.show()

    return mean_rewards, std_rewards

# %% [markdown]
# ## You can predifine your own periods and evaluate it over multiple periods, it also includes error bars

# %%
mean_rewards, std_rewards = evaluate_and_plot(model_baseline,'Baseline', env)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Episodes: 5, Mean: 3.46, Std: 2.42
# Episodes: 20, Mean: 1.75, Std: 1.35
# Episodes: 100, Mean: 2.53, Std: 1.60
# Episodes: 200, Mean: 2.46, Std: 1.83
# Episodes: 300, Mean: 2.16, Std: 1.63

# %%
env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   def _forward_input(self, allow_stdin=False):

# %% [markdown]
# ## 1st and 2nd Improvement(Reduced Observation Space and Action Space)

# %%
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 20000,
    "env_name": "l2rpn_case14_sandbox",
}
run = wandb.init(
    project="RL_Final",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)


def make_env():
    env = Gym2OpEnvWrapper(use_rewards=False, baseline=False)
    env = Monitor(env)  # record stats such as returns
    return env


env = DummyVecEnv([make_env])
# env = VecVideoRecorder(
#     env,
#     f"videos/{run.id}",
#     record_video_trigger=lambda x: x % 2000 == 0,
#     video_length=200,
# )
model_DQN =DQN(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}")
model_DQN.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        gradient_save_freq=1,
        model_save_path=f"DQN_Final/{run.id}",
        verbose=1,
    ),
)
run.finish()
env.close()
# Out:
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241028_170818-cx9fhnmt</code>
# Syncing run <strong><a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/cx9fhnmt' target="_blank">stellar-donkey-12</a></strong> to <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a>
#  View run at <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/cx9fhnmt' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/cx9fhnmt</a>
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 3.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 45       |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 6536     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.913    |
# |    n_updates        | 1608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 4        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 45       |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 6590     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.793    |
# |    n_updates        | 1622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 4.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 45       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 6664     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 1640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 4.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 45       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 6695     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0879   |
# |    n_updates        | 1648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 4.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 45       |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 6713     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.853    |
# |    n_updates        | 1653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 4.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 46       |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 6850     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 1687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 4.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 46       |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 6916     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.848    |
# |    n_updates        | 1703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 4.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 46       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 6939     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.483    |
# |    n_updates        | 1709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 4.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 46       |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 7012     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 1727     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 4.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 46       |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 7073     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.128    |
# |    n_updates        | 1743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 4.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 46       |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 7188     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 1771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 4.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 47       |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 7263     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 1790     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 4.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 47       |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 7333     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.365    |
# |    n_updates        | 1808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 4.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 47       |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 7436     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 1833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 4.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 47       |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 7493     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.79     |
# |    n_updates        | 1848     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 4.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 47       |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 7539     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.461    |
# |    n_updates        | 1859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 4.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 47       |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 7581     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.952    |
# |    n_updates        | 1870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 4.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 48       |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 7654     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.941    |
# |    n_updates        | 1888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 5.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 48       |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 7787     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 1921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 5.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 48       |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 7804     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.37     |
# |    n_updates        | 1925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 4.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 48       |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 7823     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.468    |
# |    n_updates        | 1930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 4.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 48       |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 7880     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 1944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 4.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 48       |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 7915     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 1953     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 48       |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 7934     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.802    |
# |    n_updates        | 1958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 4.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 48       |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 7954     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.319    |
# |    n_updates        | 1963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 3.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 48       |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 7978     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 1969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 3.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 48       |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 7998     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.669    |
# |    n_updates        | 1974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 48       |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 8019     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 1979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 3.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 48       |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 8070     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 1992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 3.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 48       |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 8086     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.445    |
# |    n_updates        | 1996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 3.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 48       |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 8151     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 2012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 3.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 48       |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 8167     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.558    |
# |    n_updates        | 2016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 3.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 48       |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 8198     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 2024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 3.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 48       |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 8215     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 2028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 2.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 48       |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 8229     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.542    |
# |    n_updates        | 2032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 2.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 47       |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 8244     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.299    |
# |    n_updates        | 2035     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 2.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 47       |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 8260     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.691    |
# |    n_updates        | 2039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 2.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 47       |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 8274     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.89     |
# |    n_updates        | 2043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51     |
# |    ep_rew_mean      | 1.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 47       |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 8287     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.863    |
# |    n_updates        | 2046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.07     |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 47       |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 8300     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 2049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.71     |
# |    ep_rew_mean      | 1.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 47       |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 8310     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.465    |
# |    n_updates        | 2052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.39     |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 47       |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 8320     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.395    |
# |    n_updates        | 2054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.76     |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 47       |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 8330     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.888    |
# |    n_updates        | 2057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.55     |
# |    ep_rew_mean      | 0.705    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 47       |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 8342     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 2060     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.51     |
# |    ep_rew_mean      | 0.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 47       |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 8355     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 2063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.46     |
# |    ep_rew_mean      | 0.677    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 47       |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 8369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.364    |
# |    n_updates        | 2067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.99     |
# |    ep_rew_mean      | 0.514    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 46       |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 8379     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0981   |
# |    n_updates        | 2069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78     |
# |    ep_rew_mean      | 0.437    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 46       |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 8393     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.956    |
# |    n_updates        | 2073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.81     |
# |    ep_rew_mean      | 0.442    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 46       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 8415     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 2078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.81     |
# |    ep_rew_mean      | 0.429    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 46       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 8435     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22     |
# |    n_updates        | 2083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.73     |
# |    ep_rew_mean      | 0.404    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 46       |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 8451     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.856    |
# |    n_updates        | 2087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.69     |
# |    ep_rew_mean      | 0.393    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 46       |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 8467     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.461    |
# |    n_updates        | 2091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.82     |
# |    ep_rew_mean      | 0.628    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 46       |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 8601     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.444    |
# |    n_updates        | 2125     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.13     |
# |    ep_rew_mean      | 0.763    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 47       |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 8683     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 2145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.13     |
# |    ep_rew_mean      | 0.749    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 47       |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 8699     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.753    |
# |    n_updates        | 2149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.62     |
# |    ep_rew_mean      | 0.569    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 47       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 8713     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.613    |
# |    n_updates        | 2153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.62     |
# |    ep_rew_mean      | 0.568    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 47       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 8729     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 2157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.75     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 47       |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 8873     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 2193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.12     |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 47       |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 8927     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 2206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.44     |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 47       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 8973     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.916    |
# |    n_updates        | 2218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.45     |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 47       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 8989     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.91     |
# |    n_updates        | 2222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.47     |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 47       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 9007     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 2226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.69     |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 47       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 9043     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 2235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.23     |
# |    ep_rew_mean      | 1.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 47       |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 9110     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.445    |
# |    n_updates        | 2252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.26     |
# |    ep_rew_mean      | 1.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 47       |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 9126     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 2256     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.92     |
# |    ep_rew_mean      | 1.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 47       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 9202     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.655    |
# |    n_updates        | 2275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.51     |
# |    ep_rew_mean      | 2.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 47       |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 9271     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.809    |
# |    n_updates        | 2292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.57     |
# |    ep_rew_mean      | 2.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 47       |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 9287     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 2296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.61     |
# |    ep_rew_mean      | 2.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 47       |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 9303     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.939    |
# |    n_updates        | 2300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 2.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 47       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 9336     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 2308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.83     |
# |    ep_rew_mean      | 2.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 47       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 9352     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28     |
# |    n_updates        | 2312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 2.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 47       |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 9369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.548    |
# |    n_updates        | 2317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 2.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 47       |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 9527     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.61     |
# |    n_updates        | 2356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 2.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 47       |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 9551     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.832    |
# |    n_updates        | 2362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 2.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 47       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 9579     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.764    |
# |    n_updates        | 2369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 3.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 48       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 9790     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.498    |
# |    n_updates        | 2422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 3.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 48       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 9831     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 2432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 3.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 48       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 9913     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.708    |
# |    n_updates        | 2453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 48       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 9928     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.776    |
# |    n_updates        | 2456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 3.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 48       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 9986     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 2471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 3.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 48       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 10066    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.6      |
# |    n_updates        | 2491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 3.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 48       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 10142    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.721    |
# |    n_updates        | 2510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 3.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 48       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 10174    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 2518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 3.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 48       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 10193    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.518    |
# |    n_updates        | 2523     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 3.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 49       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 10347    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.55     |
# |    n_updates        | 2561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 3.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 49       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 10438    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.244    |
# |    n_updates        | 2584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 4.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 50       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 10692    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 2647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 4.28     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 50       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 10706    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 2651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 4.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    episodes         | 2008     |
# |    fps              | 46       |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 17070    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04     |
# |    n_updates        | 4242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 2.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2012     |
# |    fps              | 46       |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 17197    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.623    |
# |    n_updates        | 4274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 3.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2016     |
# |    fps              | 47       |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 17557    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.599    |
# |    n_updates        | 4364     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 3.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2020     |
# |    fps              | 47       |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 17725    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 4406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 3.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2024     |
# |    fps              | 47       |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 17788    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0442   |
# |    n_updates        | 4421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 3.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2028     |
# |    fps              | 47       |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 17801    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.461    |
# |    n_updates        | 4425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 3.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2032     |
# |    fps              | 47       |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 17910    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 4452     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 3.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2036     |
# |    fps              | 47       |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 17981    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.98     |
# |    n_updates        | 4470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 3.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 48       |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 18048    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 4486     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 3.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2044     |
# |    fps              | 48       |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 18188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 4521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 3.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2048     |
# |    fps              | 48       |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 18406    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.55     |
# |    n_updates        | 4576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 3.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2052     |
# |    fps              | 48       |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 18503    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.438    |
# |    n_updates        | 4600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 3.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2056     |
# |    fps              | 49       |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 18706    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.395    |
# |    n_updates        | 4651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 3.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2060     |
# |    fps              | 49       |
# |    time_elapsed     | 383      |
# |    total_timesteps  | 18799    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.679    |
# |    n_updates        | 4674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 4.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2064     |
# |    fps              | 49       |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 18956    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.778    |
# |    n_updates        | 4713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 4.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2068     |
# |    fps              | 49       |
# |    time_elapsed     | 385      |
# |    total_timesteps  | 19098    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.397    |
# |    n_updates        | 4749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.5     |
# |    ep_rew_mean      | 4.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2072     |
# |    fps              | 49       |
# |    time_elapsed     | 387      |
# |    total_timesteps  | 19344    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.897    |
# |    n_updates        | 4810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.6     |
# |    ep_rew_mean      | 4.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2076     |
# |    fps              | 50       |
# |    time_elapsed     | 388      |
# |    total_timesteps  | 19470    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.614    |
# |    n_updates        | 4842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.7     |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 50       |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 19488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.892    |
# |    n_updates        | 4846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.7     |
# |    ep_rew_mean      | 5.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2084     |
# |    fps              | 50       |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 19507    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 4851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2088     |
# |    fps              | 50       |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 19584    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.558    |
# |    n_updates        | 4870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.4     |
# |    ep_rew_mean      | 5.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2092     |
# |    fps              | 50       |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 19649    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.608    |
# |    n_updates        | 4887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.6     |
# |    ep_rew_mean      | 5.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2096     |
# |    fps              | 50       |
# |    time_elapsed     | 392      |
# |    total_timesteps  | 19786    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.222    |
# |    n_updates        | 4921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 5.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 50       |
# |    time_elapsed     | 393      |
# |    total_timesteps  | 19854    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.336    |
# |    n_updates        | 4938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 5.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2104     |
# |    fps              | 50       |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 19909    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 4952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 5.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2108     |
# |    fps              | 50       |
# |    time_elapsed     | 395      |
# |    total_timesteps  | 19980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 4969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28       |
# |    ep_rew_mean      | 5.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2112     |
# |    fps              | 50       |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 19993    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.704    |
# |    n_updates        | 4973     |
# ----------------------------------
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▇▇██</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▂▂▃▄▃▃▃▃▅▅▅▄▃▂▂▃▄▅▄▁▁▁▁▁▁▁▁▁▆▆▅▆▇█</td></tr><tr><td>rollout/ep_rew_mean</td><td>▂▂▂▁▁▂▂▃▃▃▄▆▆█▇▄▆██▇▂▂▄▄▄▁▁▁▁▁▁▂▂▂▁▂▁▁▁▇</td></tr><tr><td>rollout/exploration_rate</td><td>█▇▇▆▆▅▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▁▁▁▁▂▂▂▂▂▂▆▅▆▆▆▇▇▇▇██▇▇▇█▇▇▇▇▇▆▆▆▆▆▆▆▇▇█</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>██▇▇▄▅▅▃▃▃▃▂▂▁▃▁▁▃▂▁▂▃▂▂▂▁▂▃▃▂▂▃▃▂▂▃▁▁▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>19993</td></tr><tr><td>rollout/ep_len_mean</td><td>27.96</td></tr><tr><td>rollout/ep_rew_mean</td><td>5.30303</td></tr><tr><td>rollout/exploration_rate</td><td>0.05</td></tr><tr><td>time/fps</td><td>50</td></tr><tr><td>train/learning_rate</td><td>0.0001</td></tr><tr><td>train/loss</td><td>0.7045</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-donkey-12</strong> at: <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/cx9fhnmt' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/cx9fhnmt</a><br/> View project at: <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20241028_170818-cx9fhnmt/logs</code>

# %% [markdown]
# ### DQN evaluation

# %%
env = Gym2OpEnvWrapper(use_rewards=False, baseline=False)
evaluate_policy(model_DQN, env, n_eval_episodes=200, render=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (50.55464065415086, 51.22959685241971)

# %%
env.close()

# %%
mean_rewards, std_rewards=evaluate_and_plot(model_DQN,'DQN Observation and Space Selection', env)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Episodes: 5, Mean: 76.62, Std: 52.51
# Episodes: 20, Mean: 49.06, Std: 44.48
# Episodes: 100, Mean: 49.60, Std: 49.36
# Episodes: 200, Mean: 52.69, Std: 51.86
# Episodes: 300, Mean: 52.90, Std: 54.55

# %%
mean_rewards, std_rewards
# Out:
# ([76.61705479063093,
#   49.060339212603864,
#   49.59878583665518,
#   52.69273050073505,
#   52.90002667606653],
#  [52.51238662604365,
#   44.478026962879085,
#   49.35710664304463,
#   51.85640262008412,
#   54.54834250964047])

# %%
env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   def _forward_input(self, allow_stdin=False):

# %% [markdown]
# ## DQN Replay Buffer

# %%
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 20000,
    "env_name": "l2rpn_case14_sandbox",
}
run = wandb.init(
    project="RL_Final",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)


def make_env():
    env = Gym2OpEnvWrapper(use_rewards=False, baseline=False)
    env = Monitor(env)  # record stats such as returns
    return env


env = DummyVecEnv([make_env])
model_DQN_replay_buffer = DQN(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}",replay_buffer_class=ReplayBuffer)
model_DQN_replay_buffer.learn(
     total_timesteps=config["total_timesteps"],
     callback=WandbCallback(
         gradient_save_freq=1,
         model_save_path=f"DQN_Final/{run.id}",
         verbose=1,
     ),
 )
run.finish()
env.close()
# Out:
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241028_173057-vem0zsms</code>
# Syncing run <strong><a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/vem0zsms' target="_blank">super-galaxy-13</a></strong> to <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a>
#  View run at <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/vem0zsms' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/vem0zsms</a>
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.965    |
# |    n_updates        | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22     |
# |    ep_rew_mean      | -0.202   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 34       |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 6352     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.775    |
# |    n_updates        | 1562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22     |
# |    ep_rew_mean      | -0.205   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 34       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 6367     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.75     |
# |    n_updates        | 1566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16     |
# |    ep_rew_mean      | -0.226   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 34       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 6379     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 1569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16     |
# |    ep_rew_mean      | -0.228   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 34       |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 6391     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.456    |
# |    n_updates        | 1572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16     |
# |    ep_rew_mean      | -0.233   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 34       |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 6403     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 1575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92     |
# |    ep_rew_mean      | -0.287   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 34       |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 6415     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 1578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.82     |
# |    ep_rew_mean      | -0.318   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 34       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 6427     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 1581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.81     |
# |    ep_rew_mean      | -0.329   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 34       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 6439     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 1584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.8      |
# |    ep_rew_mean      | -0.338   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 34       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 6451     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 1587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.83     |
# |    ep_rew_mean      | -0.335   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 34       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 6465     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.859    |
# |    n_updates        | 1591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.86     |
# |    ep_rew_mean      | -0.332   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 34       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 6479     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 1594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.87     |
# |    ep_rew_mean      | -0.333   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 33       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 6491     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08     |
# |    n_updates        | 1597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.9      |
# |    ep_rew_mean      | -0.329   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 33       |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 6504     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 1600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92     |
# |    ep_rew_mean      | -0.33    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 33       |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 6516     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.67     |
# |    n_updates        | 1603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.95     |
# |    ep_rew_mean      | -0.329   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 33       |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 6528     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47     |
# |    n_updates        | 1606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97     |
# |    ep_rew_mean      | -0.331   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 33       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 6540     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 1609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99     |
# |    ep_rew_mean      | -0.323   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 33       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 6553     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 1613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04     |
# |    ep_rew_mean      | -0.316   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 33       |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 6568     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.67     |
# |    n_updates        | 1616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07     |
# |    ep_rew_mean      | -0.309   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 33       |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 6582     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 1620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11     |
# |    ep_rew_mean      | -0.301   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 33       |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 6597     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 1624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17     |
# |    ep_rew_mean      | -0.283   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 33       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 6614     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.773    |
# |    n_updates        | 1628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2      |
# |    ep_rew_mean      | -0.277   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 33       |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 6628     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 1631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25     |
# |    ep_rew_mean      | -0.264   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 33       |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 6644     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.915    |
# |    n_updates        | 1635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31     |
# |    ep_rew_mean      | -0.251   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 33       |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 6660     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.92     |
# |    n_updates        | 1639     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 33       |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 6675     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 1643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39     |
# |    ep_rew_mean      | -0.223   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 33       |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 6691     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 1647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.46     |
# |    ep_rew_mean      | -0.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 33       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 6713     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.53     |
# |    n_updates        | 1653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5      |
# |    ep_rew_mean      | -0.184   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 33       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 6729     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 1657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | -0.126   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 33       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 6773     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 1668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | -0.125   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 33       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 6785     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 1671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | -0.125   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 33       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 6796     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.24     |
# |    n_updates        | 1673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | -0.126   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 33       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 6808     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 1676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | -0.115   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 33       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 6824     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 1680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | -0.111   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 33       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 6836     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 1683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | -0.112   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 33       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 6850     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 1687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86     |
# |    ep_rew_mean      | -0.111   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 33       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 6865     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 1691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88     |
# |    ep_rew_mean      | -0.106   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 33       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 6879     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.667    |
# |    n_updates        | 1694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | -0.101   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 33       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 6893     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 1698     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9      |
# |    ep_rew_mean      | -0.0974  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 33       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 6906     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 1701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91     |
# |    ep_rew_mean      | -0.0946  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 33       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 6919     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 1704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | -0.0931  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 33       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 6932     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 1707     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | -0.099   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 33       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 6945     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 1711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | -0.107   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 33       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 6957     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 1714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87     |
# |    ep_rew_mean      | -0.115   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 33       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 6969     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 1717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | -0.124   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 33       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 6981     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 1720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8      |
# |    ep_rew_mean      | -0.14    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 32       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 6994     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.729    |
# |    n_updates        | 1723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78     |
# |    ep_rew_mean      | -0.148   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 32       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 7006     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.63     |
# |    n_updates        | 1726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74     |
# |    ep_rew_mean      | -0.161   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 32       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 7018     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 1729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7      |
# |    ep_rew_mean      | -0.175   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 32       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 7030     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.25     |
# |    n_updates        | 1732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69     |
# |    ep_rew_mean      | -0.178   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 32       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 7044     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 1735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68     |
# |    ep_rew_mean      | -0.183   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 32       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 7059     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29     |
# |    n_updates        | 1739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62     |
# |    ep_rew_mean      | -0.207   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 32       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 7075     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.595    |
# |    n_updates        | 1743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59     |
# |    ep_rew_mean      | -0.216   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 32       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 7088     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 1746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3      |
# |    ep_rew_mean      | -0.273   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 32       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 7103     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 1750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31     |
# |    ep_rew_mean      | -0.27    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 32       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 7116     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 1753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33     |
# |    ep_rew_mean      | -0.268   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 32       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 7129     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 1757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33     |
# |    ep_rew_mean      | -0.268   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 32       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 7141     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 1760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26     |
# |    ep_rew_mean      | -0.279   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 32       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 7150     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 1762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24     |
# |    ep_rew_mean      | -0.282   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 32       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 7160     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 1764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24     |
# |    ep_rew_mean      | -0.283   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 32       |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 7174     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.11     |
# |    n_updates        | 1768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19     |
# |    ep_rew_mean      | -0.289   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 32       |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 7184     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 1770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15     |
# |    ep_rew_mean      | -0.293   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 32       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 7194     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 1773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 32       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 7207     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.926    |
# |    n_updates        | 1776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11     |
# |    ep_rew_mean      | -0.301   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 32       |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 7217     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.86     |
# |    n_updates        | 1779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09     |
# |    ep_rew_mean      | -0.302   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 32       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 7228     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.979    |
# |    n_updates        | 1781     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07     |
# |    ep_rew_mean      | -0.305   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 32       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 7239     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.4      |
# |    n_updates        | 1784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06     |
# |    ep_rew_mean      | -0.307   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 32       |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 7251     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 1787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03     |
# |    ep_rew_mean      | -0.309   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 32       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 7260     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 1789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04     |
# |    ep_rew_mean      | -0.305   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 32       |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 7273     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 1793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03     |
# |    ep_rew_mean      | -0.305   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 32       |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 7284     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 1795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02     |
# |    ep_rew_mean      | -0.304   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 32       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 7296     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.738    |
# |    n_updates        | 1798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01     |
# |    ep_rew_mean      | -0.303   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 32       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 7307     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.83     |
# |    n_updates        | 1801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 32       |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 7321     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 1805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05     |
# |    ep_rew_mean      | -0.298   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 32       |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 7335     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 1808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06     |
# |    ep_rew_mean      | -0.302   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 32       |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 7350     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.01     |
# |    n_updates        | 1812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06     |
# |    ep_rew_mean      | -0.312   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 31       |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 7365     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 1816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06     |
# |    ep_rew_mean      | -0.316   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 31       |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 7381     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 1820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08     |
# |    ep_rew_mean      | -0.319   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 31       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 7396     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 1823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08     |
# |    ep_rew_mean      | -0.314   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 31       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 7411     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 1827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1      |
# |    ep_rew_mean      | -0.313   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 31       |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 7426     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 1831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13     |
# |    ep_rew_mean      | -0.308   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 31       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 7442     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 1835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15     |
# |    ep_rew_mean      | -0.304   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 31       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 7456     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4      |
# |    n_updates        | 1838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21     |
# |    ep_rew_mean      | -0.302   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 31       |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 7471     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 1842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26     |
# |    ep_rew_mean      | -0.294   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 31       |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 7486     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 1846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26     |
# |    ep_rew_mean      | -0.294   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 31       |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 7500     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 1849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32     |
# |    ep_rew_mean      | -0.287   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 31       |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 7516     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 1853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | -0.0103  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 32       |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 7639     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32     |
# |    n_updates        | 1884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.47     |
# |    ep_rew_mean      | -0.00349 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 32       |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 7654     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 1888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | -0.00189 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    episodes         | 2336     |
# |    fps              | 44       |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 18669    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.319    |
# |    n_updates        | 4642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 3.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2340     |
# |    fps              | 44       |
# |    time_elapsed     | 421      |
# |    total_timesteps  | 18694    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 4648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 3        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2344     |
# |    fps              | 44       |
# |    time_elapsed     | 421      |
# |    total_timesteps  | 18709    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.703    |
# |    n_updates        | 4652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 2.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2348     |
# |    fps              | 44       |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 18744    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 4660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 2.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2352     |
# |    fps              | 44       |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 18759    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.543    |
# |    n_updates        | 4664     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 2.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2356     |
# |    fps              | 44       |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 18785    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.712    |
# |    n_updates        | 4671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 2.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2360     |
# |    fps              | 44       |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 18808    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.288    |
# |    n_updates        | 4676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2364     |
# |    fps              | 44       |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 18841    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 4685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 2.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2368     |
# |    fps              | 44       |
# |    time_elapsed     | 426      |
# |    total_timesteps  | 18938    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.355    |
# |    n_updates        | 4709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 2.28     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2372     |
# |    fps              | 44       |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 19057    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.498    |
# |    n_updates        | 4739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 2.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2376     |
# |    fps              | 44       |
# |    time_elapsed     | 428      |
# |    total_timesteps  | 19109    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.84     |
# |    n_updates        | 4752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 2.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2380     |
# |    fps              | 44       |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 19194    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.355    |
# |    n_updates        | 4773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 2.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2384     |
# |    fps              | 44       |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 19291    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.514    |
# |    n_updates        | 4797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 2.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2388     |
# |    fps              | 44       |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 19338    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.851    |
# |    n_updates        | 4809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 2.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2392     |
# |    fps              | 44       |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 19355    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.631    |
# |    n_updates        | 4813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 2.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2396     |
# |    fps              | 44       |
# |    time_elapsed     | 433      |
# |    total_timesteps  | 19466    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.96     |
# |    n_updates        | 4841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 2.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2400     |
# |    fps              | 44       |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 19484    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.363    |
# |    n_updates        | 4845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 2.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2404     |
# |    fps              | 44       |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 19521    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.368    |
# |    n_updates        | 4855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 2.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2408     |
# |    fps              | 44       |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 19538    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.423    |
# |    n_updates        | 4859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 2.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2412     |
# |    fps              | 44       |
# |    time_elapsed     | 436      |
# |    total_timesteps  | 19559    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.415    |
# |    n_updates        | 4864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 2.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2416     |
# |    fps              | 44       |
# |    time_elapsed     | 436      |
# |    total_timesteps  | 19578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.411    |
# |    n_updates        | 4869     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 2.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2420     |
# |    fps              | 44       |
# |    time_elapsed     | 437      |
# |    total_timesteps  | 19598    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 4874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2424     |
# |    fps              | 44       |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 19661    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.497    |
# |    n_updates        | 4890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2428     |
# |    fps              | 44       |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 19732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 4907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 2.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2432     |
# |    fps              | 45       |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 19846    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.654    |
# |    n_updates        | 4936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 1.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2436     |
# |    fps              | 45       |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 19888    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.159    |
# |    n_updates        | 4946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 1.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2440     |
# |    fps              | 45       |
# |    time_elapsed     | 442      |
# |    total_timesteps  | 19955    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.462    |
# |    n_updates        | 4963     |
# ----------------------------------
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▆▇▇▇▇██</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▄▃▂▂▂▁▁▁▂▂▁▁▁▁▁▁▁▁▁▂▂▂▁▂▂▂▂█▇▆▆▅▄</td></tr><tr><td>rollout/ep_rew_mean</td><td>▂▂▂▂▂▂▂▂▅▆▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▂▂▁▁▁▁▁▆█▇▆▃</td></tr><tr><td>rollout/exploration_rate</td><td>██▆▄▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▁▁▁▁▂▂▂▆▇▆▅▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▅▆▆▇███</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▇▅▆▄▃▂▂▂▃▂▂▂▁▂▂▂▄▃▃▂▃▂▂▁▁▃▃▁▃▂▃▂▃▁▃▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>19955</td></tr><tr><td>rollout/ep_len_mean</td><td>12.61</td></tr><tr><td>rollout/ep_rew_mean</td><td>1.88132</td></tr><tr><td>rollout/exploration_rate</td><td>0.05</td></tr><tr><td>time/fps</td><td>45</td></tr><tr><td>train/learning_rate</td><td>0.0001</td></tr><tr><td>train/loss</td><td>0.46249</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">super-galaxy-13</strong> at: <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/vem0zsms' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/vem0zsms</a><br/> View project at: <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20241028_173057-vem0zsms/logs</code>

# %%
env = Gym2OpEnvWrapper(use_rewards=False, baseline=False)
evaluate_policy(model_DQN_replay_buffer, env, n_eval_episodes=200, render=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (16.42090410228586, 18.640485850055267)

# %%
env.close()

# %%
env = Gym2OpEnvWrapper(use_rewards=False, baseline=False)
mean_rewards, std_rewards=evaluate_and_plot(model_DQN_replay_buffer,'Replay_Buffer', env)
# Out:
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Episodes: 5, Mean: 24.31, Std: 26.51
# Episodes: 20, Mean: 14.20, Std: 11.22
# Episodes: 100, Mean: 17.64, Std: 17.59
# Episodes: 200, Mean: 17.98, Std: 18.96
# Episodes: 300, Mean: 17.50, Std: 16.72

# %%
mean_rewards, std_rewards

# %%
env.close()

# %% [markdown]
# ## Tweaking Of Rewards with DQN Replay Buffer

# %%
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 20000,
    "env_name": "l2rpn_case14_sandbox",
}
run = wandb.init(
    project="RL_Final",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)


def make_env():
    env = Gym2OpEnvWrapper(use_rewards=True, baseline=False, other_rewards={"linesreconnected": LinesReconnectedReward,'linescapacity': LinesCapacityReward,
                                          'closetoOverflow':CloseToOverflowReward, 'alert':AlertReward})
    env = Monitor(env)  # record stats such as returns
    return env


env = DummyVecEnv([make_env])
model_replay_buffer_reward = DQN(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}", replay_buffer_class=ReplayBuffer)
model_replay_buffer_reward.learn(
     total_timesteps=config["total_timesteps"],
     callback=WandbCallback(
         gradient_save_freq=1,
         model_save_path=f"DQN_Final/{run.id}",
         verbose=1,
     ),
 )
run.finish()
env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   def _forward_input(self, allow_stdin=False):
# Finishing last run (ID:6fx2pkbx) before initializing another...
#  View run <strong style="color:#cdcd00">stellar-shadow-15</strong> at: <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/6fx2pkbx' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/6fx2pkbx</a><br/> View project at: <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241028_181412-6fx2pkbx/logs</code>
# Successfully finished last run (ID:6fx2pkbx). Initializing new run:<br/>
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241028_181453-oe3saqmh</code>
# Syncing run <strong><a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/oe3saqmh' target="_blank">avid-grass-16</a></strong> to <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a>
#  View run at <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/oe3saqmh' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/oe3saqmh</a>
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.53     |
# |    n_updates        | 1514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 33       |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 6175     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.759    |
# |    n_updates        | 1518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 5.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 33       |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 6191     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.619    |
# |    n_updates        | 1522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 5.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 33       |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 6213     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 1528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 5.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 33       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 6227     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.988    |
# |    n_updates        | 1531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 5.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 33       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 6241     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 1535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 5.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 32       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 6255     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 1538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 5.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 32       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 6267     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 1541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 5.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 32       |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 6281     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.288    |
# |    n_updates        | 1545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 5.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 32       |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 6295     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14     |
# |    n_updates        | 1548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 5.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 32       |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 6309     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.925    |
# |    n_updates        | 1552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 5.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 32       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 6323     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 1555     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 5.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 32       |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 6339     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 5.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 32       |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 6355     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.65     |
# |    n_updates        | 1563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 5.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 32       |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 6369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1        |
# |    n_updates        | 1567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 4.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 32       |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 6385     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 1571     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 4.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 32       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 6402     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 1575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 3.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 32       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 6416     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.629    |
# |    n_updates        | 1578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 3        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 32       |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 6430     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 1582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 2.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 32       |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 6446     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 1586     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51     |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 32       |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 6461     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 1590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.31     |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 32       |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 6475     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97     |
# |    n_updates        | 1593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.15     |
# |    ep_rew_mean      | 1.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 32       |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 6489     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41     |
# |    n_updates        | 1597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 32       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 6505     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.9      |
# |    n_updates        | 1601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4        |
# |    ep_rew_mean      | 0.236    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 32       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 6518     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 1604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76     |
# |    ep_rew_mean      | 0.184    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 32       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 6533     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 1608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 32       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 6611     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.853    |
# |    n_updates        | 1627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33     |
# |    ep_rew_mean      | 0.389    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 32       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 6624     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 1630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | 0.378    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 32       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 6639     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98     |
# |    n_updates        | 1634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42     |
# |    ep_rew_mean      | 0.437    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 32       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 6669     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 1642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43     |
# |    ep_rew_mean      | 0.443    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 32       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 6684     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 1645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.62     |
# |    ep_rew_mean      | 0.514    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 32       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 6717     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.599    |
# |    n_updates        | 1654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.64     |
# |    ep_rew_mean      | 0.526    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 32       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 6731     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 1657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.69     |
# |    ep_rew_mean      | 0.549    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 32       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 6750     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.24     |
# |    n_updates        | 1662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.69     |
# |    ep_rew_mean      | 0.558    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 32       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 6764     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 1665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.69     |
# |    ep_rew_mean      | 0.571    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 32       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 6778     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.22     |
# |    n_updates        | 1669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.67     |
# |    ep_rew_mean      | 0.576    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 32       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 6790     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 1672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.64     |
# |    ep_rew_mean      | 0.569    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 32       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 6803     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 1675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | 0.555    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 32       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 6816     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.63     |
# |    n_updates        | 1678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.62     |
# |    ep_rew_mean      | 0.559    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 32       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 6831     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 1682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.6      |
# |    ep_rew_mean      | 0.554    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 32       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 6845     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 1686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.59     |
# |    ep_rew_mean      | 0.556    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 32       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 6861     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 1690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | 0.557    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 32       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 6877     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 1694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | 0.564    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 32       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 6891     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.96     |
# |    n_updates        | 1697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.59     |
# |    ep_rew_mean      | 0.557    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 32       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 6905     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 1701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.58     |
# |    ep_rew_mean      | 0.547    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 32       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 6919     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54     |
# |    n_updates        | 1704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.6      |
# |    ep_rew_mean      | 0.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 32       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 6935     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 1708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.62     |
# |    ep_rew_mean      | 0.556    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 32       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 6951     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 1712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | 0.553    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 32       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 6966     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 1716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.65     |
# |    ep_rew_mean      | 0.565    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 32       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 6983     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.85     |
# |    n_updates        | 1720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.65     |
# |    ep_rew_mean      | 0.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 32       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 6998     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25     |
# |    n_updates        | 1724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.361    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 32       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 7014     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.39     |
# |    n_updates        | 1728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.373    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 32       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 7029     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66     |
# |    n_updates        | 1732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06     |
# |    ep_rew_mean      | 0.379    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 32       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 7045     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 1736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93     |
# |    ep_rew_mean      | 0.336    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 32       |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 7062     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 1740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91     |
# |    ep_rew_mean      | 0.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 31       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 7075     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99     |
# |    n_updates        | 1743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74     |
# |    ep_rew_mean      | 0.269    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 31       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 7091     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.32     |
# |    n_updates        | 1747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76     |
# |    ep_rew_mean      | 0.272    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 31       |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 7107     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 1751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74     |
# |    ep_rew_mean      | 0.269    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 31       |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 7124     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52     |
# |    n_updates        | 1755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76     |
# |    ep_rew_mean      | 0.271    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 31       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 7140     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 1759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76     |
# |    ep_rew_mean      | 0.271    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 31       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 7154     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 1763     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79     |
# |    ep_rew_mean      | 0.278    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 31       |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 7169     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 1767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | 0.282    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 31       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 7184     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.974    |
# |    n_updates        | 1770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 31       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 7199     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 1774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 31       |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 7213     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28     |
# |    n_updates        | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | 0.298    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 31       |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 7229     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 1782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | 0.296    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 31       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 7245     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84     |
# |    n_updates        | 1786     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | 0.302    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 31       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 7262     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49     |
# |    n_updates        | 1790     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | 0.293    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 31       |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 7273     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 1793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | 0.303    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 31       |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 7290     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 1797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | 0.309    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 31       |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 7304     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81     |
# |    n_updates        | 1800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83     |
# |    ep_rew_mean      | 0.306    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 31       |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 7318     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72     |
# |    n_updates        | 1804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | 0.303    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 31       |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 7333     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04     |
# |    n_updates        | 1808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83     |
# |    ep_rew_mean      | 0.308    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 31       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 7349     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.28     |
# |    n_updates        | 1812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78     |
# |    ep_rew_mean      | 0.294    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 31       |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 7361     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.4      |
# |    n_updates        | 1815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79     |
# |    ep_rew_mean      | 0.299    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 31       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 7377     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 1819     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78     |
# |    ep_rew_mean      | 0.293    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 31       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 7392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.995    |
# |    n_updates        | 1822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75     |
# |    ep_rew_mean      | 0.279    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 31       |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 7404     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41     |
# |    n_updates        | 1825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.66     |
# |    ep_rew_mean      | 0.501    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 31       |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 7511     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.38     |
# |    n_updates        | 1852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.81     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 31       |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 7543     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.53     |
# |    n_updates        | 1860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.79     |
# |    ep_rew_mean      | 0.798    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 32       |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 7654     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.74     |
# |    n_updates        | 1888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.79     |
# |    ep_rew_mean      | 0.799    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 32       |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 7670     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 1892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.75     |
# |    ep_rew_mean      | 0.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 32       |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 7682     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 1895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.74     |
# |    ep_rew_mean      | 0.786    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 32       |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 7698     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.925    |
# |    n_updates        | 1899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.74     |
# |    ep_rew_mean      | 0.789    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 32       |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 7714     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29     |
# |    n_updates        | 1903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.74     |
# |    ep_rew_mean      | 0.789    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 32       |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 7728     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 1906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.75     |
# |    ep_rew_mean      | 0.795    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 32       |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 7744     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31     |
# |    n_updates        | 1910     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.77     |
# |    ep_rew_mean      | 0.801    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1468     |
# ...
# |    episodes         | 2348     |
# |    fps              | 43       |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 18079    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 4494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.2     |
# |    ep_rew_mean      | 7.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2352     |
# |    fps              | 43       |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 18165    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 4516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 7.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2356     |
# |    fps              | 43       |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 18198    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 4524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | 7.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2360     |
# |    fps              | 43       |
# |    time_elapsed     | 421      |
# |    total_timesteps  | 18287    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.557    |
# |    n_updates        | 4546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 6.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2364     |
# |    fps              | 43       |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 18494    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.11     |
# |    n_updates        | 4598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 6.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2368     |
# |    fps              | 43       |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 18528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 4606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 6.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2372     |
# |    fps              | 43       |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 18571    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.96     |
# |    n_updates        | 4617     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 6.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2376     |
# |    fps              | 43       |
# |    time_elapsed     | 426      |
# |    total_timesteps  | 18612    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 4627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 6.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2380     |
# |    fps              | 43       |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 18678    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.505    |
# |    n_updates        | 4644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 5.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2384     |
# |    fps              | 43       |
# |    time_elapsed     | 428      |
# |    total_timesteps  | 18740    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.05     |
# |    n_updates        | 4659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 5.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2388     |
# |    fps              | 43       |
# |    time_elapsed     | 429      |
# |    total_timesteps  | 18823    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 4680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2392     |
# |    fps              | 43       |
# |    time_elapsed     | 429      |
# |    total_timesteps  | 18840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.46     |
# |    n_updates        | 4684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 4.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2396     |
# |    fps              | 43       |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 18858    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 4689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2400     |
# |    fps              | 43       |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 18877    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.964    |
# |    n_updates        | 4694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 4.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2404     |
# |    fps              | 44       |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 19074    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25     |
# |    n_updates        | 4743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 4.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2408     |
# |    fps              | 44       |
# |    time_elapsed     | 433      |
# |    total_timesteps  | 19165    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 4766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 4.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2412     |
# |    fps              | 44       |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 19297    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 4799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 4.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2416     |
# |    fps              | 44       |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 19323    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.546    |
# |    n_updates        | 4805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 4.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2420     |
# |    fps              | 44       |
# |    time_elapsed     | 436      |
# |    total_timesteps  | 19393    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.736    |
# |    n_updates        | 4823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 4.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2424     |
# |    fps              | 44       |
# |    time_elapsed     | 437      |
# |    total_timesteps  | 19469    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.742    |
# |    n_updates        | 4842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 4.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2428     |
# |    fps              | 44       |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 19606    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.996    |
# |    n_updates        | 4876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2432     |
# |    fps              | 44       |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 19627    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.475    |
# |    n_updates        | 4881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 4.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2436     |
# |    fps              | 44       |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 19751    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.793    |
# |    n_updates        | 4912     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 3.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2440     |
# |    fps              | 44       |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 19765    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.95     |
# |    n_updates        | 4916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 3.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2444     |
# |    fps              | 44       |
# |    time_elapsed     | 442      |
# |    total_timesteps  | 19849    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.343    |
# |    n_updates        | 4937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 3.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2448     |
# |    fps              | 44       |
# |    time_elapsed     | 443      |
# |    total_timesteps  | 19907    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.61     |
# |    n_updates        | 4951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 3.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2452     |
# |    fps              | 44       |
# |    time_elapsed     | 443      |
# |    total_timesteps  | 19935    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.606    |
# |    n_updates        | 4958     |
# ----------------------------------
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▄▄▅▅▅▅▆▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▄▁▁▂▂▂▁▁▁▁██▅▇█▅▅</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▂▂▂▁▁▅▂▁▁▂▁▁▁▁▂▁▁▁▂▇█▆▅▅</td></tr><tr><td>rollout/exploration_rate</td><td>███▅▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▁▂▂▂▁▁▁▁▂▂▂▂▂▂▂▃▄▄▄▄▄▄▄▄▄▄▄▄▄▄▃▅▅▆▆▇▇███</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▇█▆▆▆▅▃▄▃▃▂▂▂▃▂▃▃▂▂▂▂▂▂▂▂▂▃▄▃▃▂▃▃▁▂▁▃▂▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>19935</td></tr><tr><td>rollout/ep_len_mean</td><td>17.7</td></tr><tr><td>rollout/ep_rew_mean</td><td>3.7523</td></tr><tr><td>rollout/exploration_rate</td><td>0.05</td></tr><tr><td>time/fps</td><td>44</td></tr><tr><td>train/learning_rate</td><td>0.0001</td></tr><tr><td>train/loss</td><td>0.60584</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">avid-grass-16</strong> at: <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/oe3saqmh' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/oe3saqmh</a><br/> View project at: <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20241028_181453-oe3saqmh/logs</code>

# %%
env = Gym2OpEnvWrapper(use_rewards=False, baseline=False)
evaluate_policy(model_replay_buffer_reward, env, n_eval_episodes=200, render=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   def _forward_input(self, allow_stdin=False):
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (43.49364445352112, 22.618759307432832)

# %%
env.close()

# %%
mean_rewards, std_rewards=evaluate_and_plot(model_replay_buffer_reward,'Replay Buffer Tweaked Rewards', env)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Episodes: 5, Mean: 26.79, Std: 12.86
# Episodes: 20, Mean: 39.28, Std: 24.27
# Episodes: 100, Mean: 48.06, Std: 26.91
# Episodes: 200, Mean: 39.76, Std: 25.27
# Episodes: 300, Mean: 45.09, Std: 24.26

# %%
mean_rewards, std_rewards
# Out:
# ([26.786687353253363,
#   39.28340074932203,
#   48.064651374071836,
#   39.761091787498444,
#   45.09192591093015],
#  [12.8583047632128,
#   24.266709352444533,
#   26.913010099258685,
#   25.272738703905755,
#   24.257667932238608])

# %% [markdown]
# ## DQN Target Network without tweaked rewards

# %%
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 20000,
    "env_name": "l2rpn_case14_sandbox",
}
run = wandb.init(
    project="RL_Final",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)


def make_env():
    env = Gym2OpEnvWrapper(use_rewards=False, baseline=False,other_rewards={"linesreconnected": LinesReconnectedReward,'linescapacity': LinesCapacityReward,
                                          'closetoOverflow':CloseToOverflowReward, 'alert':AlertReward})
    env = Monitor(env)  # record stats such as returns
    return env


env = DummyVecEnv([make_env])
model_DQN_Target = DQN(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}",
    batch_size=256,
    tau=1.0,
    gamma=0.99,
    learning_starts = 100,
    train_freq=4,
    gradient_steps=1,
    target_update_interval=500,
    exploration_fraction=0.2,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.05,
    max_grad_norm=10)

model_DQN_Target.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        gradient_save_freq=1,
        model_save_path=f"DQN_Final/{run.id}",
        verbose=1,
    ),
)
run.finish()
env.close()
# Out:
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241028_174804-wivvukgz</code>
# Syncing run <strong><a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/wivvukgz' target="_blank">peach-monkey-14</a></strong> to <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a>
#  View run at <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/wivvukgz' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/wivvukgz</a>
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16     |
# |    n_updates        | 518      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.35     |
# |    ep_rew_mean      | 0.199    |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 24       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 2187     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.3      |
# |    n_updates        | 521      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32     |
# |    ep_rew_mean      | 0.192    |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 24       |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 2201     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.36     |
# |    n_updates        | 525      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | 0.193    |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 23       |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 2216     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 528      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33     |
# |    ep_rew_mean      | 0.204    |
# |    exploration_rate | 0.469    |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 23       |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 2235     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 533      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | 0.201    |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 24       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 2261     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 540      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31     |
# |    ep_rew_mean      | 0.178    |
# |    exploration_rate | 0.459    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 24       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 2278     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 544      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | 0.187    |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 24       |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 2301     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.22     |
# |    n_updates        | 550      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.29     |
# |    ep_rew_mean      | 0.171    |
# |    exploration_rate | 0.45     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 24       |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 2317     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99     |
# |    n_updates        | 554      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17     |
# |    ep_rew_mean      | 0.135    |
# |    exploration_rate | 0.446    |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 24       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 2334     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41     |
# |    n_updates        | 558      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12     |
# |    ep_rew_mean      | 0.129    |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 24       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 2349     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97     |
# |    n_updates        | 562      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | 0.124    |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 24       |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 2364     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 565      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | 0.138    |
# |    exploration_rate | 0.435    |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 24       |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 2380     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.28     |
# |    n_updates        | 569      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12     |
# |    ep_rew_mean      | 0.129    |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 24       |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 2394     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.12     |
# |    n_updates        | 573      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04     |
# |    ep_rew_mean      | 0.108    |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 24       |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 2407     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14     |
# |    n_updates        | 576      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.104    |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 24       |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 2424     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32     |
# |    n_updates        | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.0997   |
# |    exploration_rate | 0.42     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 24       |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 2444     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.85     |
# |    n_updates        | 585      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.103    |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 24       |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 2459     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.63     |
# |    n_updates        | 589      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04     |
# |    ep_rew_mean      | 0.102    |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 23       |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 2470     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.13     |
# |    n_updates        | 592      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | 0.0791   |
# |    exploration_rate | 0.41     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 23       |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 2486     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93     |
# |    n_updates        | 596      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.0933   |
# |    exploration_rate | 0.404    |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 23       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 2510     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.33     |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.0849   |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 23       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 2528     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.91     |
# |    n_updates        | 606      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | 0.113    |
# |    exploration_rate | 0.394    |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 23       |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 2551     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.77     |
# |    n_updates        | 612      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 23       |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 2566     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.4      |
# |    n_updates        | 616      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.51     |
# |    ep_rew_mean      | 0.239    |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 23       |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 2609     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.59     |
# |    n_updates        | 627      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.83     |
# |    ep_rew_mean      | 0.345    |
# |    exploration_rate | 0.368    |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 24       |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 2659     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.99     |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.01     |
# |    ep_rew_mean      | 0.382    |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 24       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 2688     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.23     |
# |    n_updates        | 646      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.13     |
# |    ep_rew_mean      | 0.417    |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 24       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 2714     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.05     |
# |    n_updates        | 653      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.11     |
# |    ep_rew_mean      | 0.416    |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 24       |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 2727     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.49     |
# |    n_updates        | 656      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.09     |
# |    ep_rew_mean      | 0.411    |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 24       |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 2744     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.89     |
# |    n_updates        | 660      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.27     |
# |    ep_rew_mean      | 0.472    |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 24       |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 2788     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.52     |
# |    n_updates        | 671      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.31     |
# |    ep_rew_mean      | 0.489    |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 24       |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 2809     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.55     |
# |    n_updates        | 677      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.26     |
# |    ep_rew_mean      | 0.485    |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 24       |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 2827     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.49     |
# |    n_updates        | 681      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.24     |
# |    ep_rew_mean      | 0.482    |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 24       |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 2841     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92     |
# |    n_updates        | 685      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.21     |
# |    ep_rew_mean      | 0.485    |
# |    exploration_rate | 0.322    |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 24       |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 2855     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.66     |
# |    n_updates        | 688      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.19     |
# |    ep_rew_mean      | 0.49     |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 24       |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 2868     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45     |
# |    n_updates        | 691      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.28     |
# |    ep_rew_mean      | 0.534    |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 24       |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 2892     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.59     |
# |    n_updates        | 697      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.45     |
# |    ep_rew_mean      | 0.589    |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 24       |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 2925     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58     |
# |    n_updates        | 706      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.52     |
# |    ep_rew_mean      | 0.619    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 24       |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 2946     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 711      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.55     |
# |    ep_rew_mean      | 0.643    |
# |    exploration_rate | 0.297    |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 24       |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 2962     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.68     |
# |    n_updates        | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.56     |
# |    ep_rew_mean      | 0.659    |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 24       |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 2980     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.85     |
# |    n_updates        | 719      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.46     |
# |    ep_rew_mean      | 0.638    |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 24       |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 2990     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.03     |
# |    n_updates        | 722      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.39     |
# |    ep_rew_mean      | 0.632    |
# |    exploration_rate | 0.288    |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 24       |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 2998     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32     |
# |    n_updates        | 724      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.43     |
# |    ep_rew_mean      | 0.64     |
# |    exploration_rate | 0.284    |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 24       |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 3013     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.01     |
# |    n_updates        | 728      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.46     |
# |    ep_rew_mean      | 0.657    |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 24       |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 3032     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.11     |
# |    n_updates        | 732      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.34     |
# |    ep_rew_mean      | 0.629    |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 24       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 3044     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.07     |
# |    n_updates        | 735      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.35     |
# |    ep_rew_mean      | 0.636    |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 24       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 3063     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.06     |
# |    n_updates        | 740      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.21     |
# |    ep_rew_mean      | 0.607    |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 24       |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 3072     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.95     |
# |    n_updates        | 742      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.34     |
# |    ep_rew_mean      | 0.641    |
# |    exploration_rate | 0.264    |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 24       |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 3100     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.56     |
# |    n_updates        | 749      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.99     |
# |    ep_rew_mean      | 0.522    |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 24       |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 3108     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 751      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.66     |
# |    ep_rew_mean      | 0.421    |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 24       |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 3125     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.64     |
# |    n_updates        | 756      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.51     |
# |    ep_rew_mean      | 0.388    |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 24       |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 3139     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.36     |
# |    n_updates        | 759      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43     |
# |    ep_rew_mean      | 0.363    |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 24       |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 3157     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41     |
# |    n_updates        | 764      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.44     |
# |    ep_rew_mean      | 0.365    |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 24       |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 3171     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.67     |
# |    n_updates        | 767      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.44     |
# |    ep_rew_mean      | 0.37     |
# |    exploration_rate | 0.243    |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 25       |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 3188     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.5      |
# |    n_updates        | 771      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17     |
# |    ep_rew_mean      | 0.298    |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 25       |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 3205     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.66     |
# |    n_updates        | 776      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.236    |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 24       |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 3217     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.57     |
# |    n_updates        | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# |    ep_rew_mean      | 0.275    |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 24       |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 3237     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.69     |
# |    n_updates        | 784      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# |    ep_rew_mean      | 0.268    |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 24       |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 3251     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.99     |
# |    n_updates        | 787      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | 0.336    |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 25       |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 3292     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71     |
# |    n_updates        | 797      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.55     |
# |    ep_rew_mean      | 0.374    |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 25       |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 3323     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.99     |
# |    n_updates        | 805      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.89     |
# |    ep_rew_mean      | 0.441    |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 25       |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 3381     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21     |
# |    n_updates        | 820      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.77     |
# |    ep_rew_mean      | 0.397    |
# |    exploration_rate | 0.192    |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 25       |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 3402     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.56     |
# |    n_updates        | 825      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.8      |
# |    ep_rew_mean      | 0.391    |
# |    exploration_rate | 0.186    |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 25       |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 3426     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08     |
# |    n_updates        | 831      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.77     |
# |    ep_rew_mean      | 0.375    |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 25       |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 3439     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.33     |
# |    n_updates        | 834      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.79     |
# |    ep_rew_mean      | 0.384    |
# |    exploration_rate | 0.178    |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 25       |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 3459     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.73     |
# |    n_updates        | 839      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.88     |
# |    ep_rew_mean      | 0.408    |
# |    exploration_rate | 0.174    |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 25       |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 3478     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98     |
# |    n_updates        | 844      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.01     |
# |    ep_rew_mean      | 0.433    |
# |    exploration_rate | 0.169    |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 25       |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 3499     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.79     |
# |    n_updates        | 849      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.05     |
# |    ep_rew_mean      | 0.447    |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 25       |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 3518     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.5      |
# |    n_updates        | 854      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.07     |
# |    ep_rew_mean      | 0.437    |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 25       |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 3539     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.8      |
# |    n_updates        | 859      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.1      |
# |    ep_rew_mean      | 0.449    |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 25       |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 3554     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.05     |
# |    n_updates        | 863      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.09     |
# |    ep_rew_mean      | 0.445    |
# |    exploration_rate | 0.152    |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 25       |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 3572     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.49     |
# |    n_updates        | 867      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.64     |
# |    ep_rew_mean      | 0.602    |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 26       |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 3636     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 883      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.67     |
# |    ep_rew_mean      | 0.603    |
# |    exploration_rate | 0.129    |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 26       |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 3667     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.8      |
# |    n_updates        | 891      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.16     |
# |    ep_rew_mean      | 0.706    |
# |    exploration_rate | 0.116    |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 26       |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 3724     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.47     |
# |    n_updates        | 905      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.09     |
# |    ep_rew_mean      | 0.687    |
# |    exploration_rate | 0.113    |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 26       |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 3734     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 908      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.39     |
# |    ep_rew_mean      | 0.789    |
# |    exploration_rate | 0.103    |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 26       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 3778     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13     |
# |    n_updates        | 919      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.36     |
# |    ep_rew_mean      | 0.774    |
# |    exploration_rate | 0.0992   |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 26       |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 3793     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 923      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.32     |
# |    ep_rew_mean      | 0.757    |
# |    exploration_rate | 0.0968   |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 26       |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 3803     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.96     |
# |    n_updates        | 925      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.27     |
# |    ep_rew_mean      | 0.733    |
# |    exploration_rate | 0.0939   |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 26       |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 3815     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32     |
# |    n_updates        | 928      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.28     |
# |    ep_rew_mean      | 0.733    |
# |    exploration_rate | 0.0897   |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 26       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 3833     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.91     |
# |    n_updates        | 933      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.82     |
# |    ep_rew_mean      | 0.878    |
# |    exploration_rate | 0.074    |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 26       |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 3899     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.38     |
# |    n_updates        | 949      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.12     |
# |    ep_rew_mean      | 0.959    |
# |    exploration_rate | 0.0621   |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 26       |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 3949     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.48     |
# |    n_updates        | 962      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.81     |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 27       |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 4032     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.55     |
# |    n_updates        | 982      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.54     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 27       |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 4046     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.95     |
# |    n_updates        | 986      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.38     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 27       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 4061     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.03     |
# |    n_updates        | 990      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.94     |
# |    ep_rew_mean      | 0.904    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 27       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 4075     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.89     |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.85     |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 27       |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 4187     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07     |
# |    n_updates        | 1021     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.71     |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 27       |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 4197     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.22     |
# |    n_updates        | 1024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.67     |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    episodes         | 1764     |
# |    fps              | 49       |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 17451    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92     |
# |    n_updates        | 4337     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 4.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1768     |
# |    fps              | 49       |
# |    time_elapsed     | 353      |
# |    total_timesteps  | 17589    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.4      |
# |    n_updates        | 4372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 4.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1772     |
# |    fps              | 49       |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 17691    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92     |
# |    n_updates        | 4397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 4.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1776     |
# |    fps              | 49       |
# |    time_elapsed     | 355      |
# |    total_timesteps  | 17716    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31     |
# |    n_updates        | 4403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 3.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1780     |
# |    fps              | 49       |
# |    time_elapsed     | 355      |
# |    total_timesteps  | 17733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45     |
# |    n_updates        | 4408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 4.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1784     |
# |    fps              | 49       |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 17829    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.02     |
# |    n_updates        | 4432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 4.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1788     |
# |    fps              | 49       |
# |    time_elapsed     | 357      |
# |    total_timesteps  | 17874    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45     |
# |    n_updates        | 4443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 4.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1792     |
# |    fps              | 50       |
# |    time_elapsed     | 358      |
# |    total_timesteps  | 17933    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.4      |
# |    n_updates        | 4458     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 4.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1796     |
# |    fps              | 50       |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 18029    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.57     |
# |    n_updates        | 4482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 4.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 50       |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 18129    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47     |
# |    n_updates        | 4507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 4.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1804     |
# |    fps              | 50       |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 18259    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 4539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 3.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1808     |
# |    fps              | 50       |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 18297    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.24     |
# |    n_updates        | 4549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1812     |
# |    fps              | 50       |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 18357    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.36     |
# |    n_updates        | 4564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 4.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1816     |
# |    fps              | 50       |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 18578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 4619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 4.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1820     |
# |    fps              | 51       |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 18800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 4674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 5.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1824     |
# |    fps              | 51       |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 19006    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.97     |
# |    n_updates        | 4726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 5.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1828     |
# |    fps              | 51       |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 19108    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72     |
# |    n_updates        | 4751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 6.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1832     |
# |    fps              | 51       |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 19224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.73     |
# |    n_updates        | 4780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 6.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1836     |
# |    fps              | 51       |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 19353    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.19     |
# |    n_updates        | 4813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 6.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1840     |
# |    fps              | 51       |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 19390    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.62     |
# |    n_updates        | 4822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1844     |
# |    fps              | 51       |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 19530    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04     |
# |    n_updates        | 4857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 6.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1848     |
# |    fps              | 51       |
# |    time_elapsed     | 377      |
# |    total_timesteps  | 19618    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 4879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.6     |
# |    ep_rew_mean      | 7.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1852     |
# |    fps              | 52       |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 19907    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.94     |
# |    n_updates        | 4951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.3     |
# |    ep_rew_mean      | 7.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1856     |
# |    fps              | 52       |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 19949    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.79     |
# |    n_updates        | 4962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 7.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1860     |
# |    fps              | 52       |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 19961    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.36     |
# |    n_updates        | 4965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.2     |
# |    ep_rew_mean      | 7.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1864     |
# |    fps              | 52       |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 19973    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.86     |
# |    n_updates        | 4968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 7.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1868     |
# |    fps              | 52       |
# |    time_elapsed     | 382      |
# |    total_timesteps  | 19986    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 4971     |
# ----------------------------------
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▂▃▃▃▃▅▇▆▆▆▇███▇▇▆▆▅▅▆</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▅▆▇███▆▆</td></tr><tr><td>rollout/exploration_rate</td><td>█▇▇▇▇▆▆▆▅▅▅▅▅▅▄▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▃▃▃▄▄▅▆▇▇▇█████</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▄▅▅▁▁▂▁▂▃▂▄▄▄▅▆▃▆▆▂█▄▃▄▅▇▆▇▃▅▆▅▆▄▆▄▅▆▃▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>19986</td></tr><tr><td>rollout/ep_len_mean</td><td>23.97</td></tr><tr><td>rollout/ep_rew_mean</td><td>7.11576</td></tr><tr><td>rollout/exploration_rate</td><td>0.05</td></tr><tr><td>time/fps</td><td>52</td></tr><tr><td>train/learning_rate</td><td>0.0001</td></tr><tr><td>train/loss</td><td>2.24423</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peach-monkey-14</strong> at: <a href='https://wandb.ai/2445617-wits-university/RL_Final/runs/wivvukgz' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final/runs/wivvukgz</a><br/> View project at: <a href='https://wandb.ai/2445617-wits-university/RL_Final' target="_blank">https://wandb.ai/2445617-wits-university/RL_Final</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20241028_174804-wivvukgz/logs</code>

# %%
env = Gym2OpEnvWrapper(use_rewards=False, baseline=False)
evaluate_policy(model_DQN_Target, env, n_eval_episodes=200, render=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/grid2op/gym_compat/discrete_gym_actspace.py:260: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (50.80063688844442, 50.73703538251326)

# %%
env.close()

# %%
mean_rewards, std_rewards=evaluate_and_plot(model_DQN_Target,"Target Network", env)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Episodes: 5, Mean: 66.40, Std: 38.18
# Episodes: 20, Mean: 84.49, Std: 55.54
# Episodes: 100, Mean: 44.41, Std: 39.59
# Episodes: 200, Mean: 50.20, Std: 51.48
# Episodes: 300, Mean: 49.75, Std: 48.61
